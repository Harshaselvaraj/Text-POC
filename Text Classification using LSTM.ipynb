# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding
## Plotly
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Others
import nltk
import string
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
import re
from nltk.stem.snowball import SnowballStemmer 

from sklearn.manifold import TSNE
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from scipy.stats import itemfreq

# %%
df = pd.read_csv("Account Type Data.csv",encoding="ISO-8859-1")
del df['CA_Account_Number']
del df['CA_FS_Caption']
#del df['CA_PL_Indicator']

# %%
df1=df[df['CA_PL_Indicator']=="BS"]
df2=df[df['CA_PL_Indicator']=="PL"]
del df1['CA_PL_Indicator']
del df2['CA_PL_Indicator']

# %%
df1.head()
# Out:
#           CA_Account_Name CA_Account_Type
# 0            Total Assets          Assets
# 1                    Cash          Assets
# 2    Payroll Cash Account          Assets
# 3  Short Term Investments          Assets
# 4   Long Term Investments          Assets

# %%
df2.head()
# Out:
#                    CA_Account_Name CA_Account_Type
# 59            Maintenance Material         Expense
# 170  Sales Revenue - Earned Billed         Revenue
# 171         Sales Revenue - Billed         Revenue
# 172       Sales Revenue - Unbilled         Revenue
# 173                       Hardware         Revenue

# %%
df1 = df1.dropna()
df1 = df1[df1['CA_Account_Name'].apply(lambda x: not x.isnumeric())]
df1 = df1.dropna(subset=['CA_Account_Name','CA_Account_Type'])

df2 = df2.dropna()
df2 = df2[df2['CA_Account_Name'].apply(lambda x: not x.isnumeric())]
df2 = df2.dropna(subset=['CA_Account_Name','CA_Account_Type'])

# %%
itemfreq(df1['CA_Account_Name'])
# Out:
# array([[' Payable Assets - Guarantee', 1],
#        [' VAT Payable', 1],
#        [' Zapasy pó?fabrykatów', 1],
#        ...,
#        ['Zero VAT - output', 1],
#        ['Zysk niepodzielony', 1],
#        ['liaison', 1]], dtype=object)

# %%
itemfreq(df1['CA_Account_Type'])
# Out:
# array([['Assets', 2351],
#        ['Equity', 213],
#        ['Liabilities', 1280]], dtype=object)

# %%
itemfreq(df2['CA_Account_Type'])
# Out:
# array([['Expense', 2293],
#        ['Revenue', 651]], dtype=object)

# %%
len(df1)
# Out:
# 3844

# %%
len(df2)
# Out:
# 2944

# %%
labels1 = df1['CA_Account_Type'].map(lambda x : 0 if x == 'Assets' else 1 if x == 'Equity' else 2)
labels2 = df2['CA_Account_Type'].map(lambda x : 0 if x == 'Expense' else 1)

# %%
itemfreq(labels1)
# Out:
# array([[   0, 2351],
#        [   1,  213],
#        [   2, 1280]], dtype=int64)

# %%
itemfreq(labels2)
# Out:
# array([[   0, 2293],
#        [   1,  651]], dtype=int64)

# %%
def words(text): 
    return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('accounting terms v1.txt',encoding='utf-8').read()))

#"Probability of `word`."
def P(word, N=sum(WORDS.values())): 
    return WORDS[word] / N

#"Most probable spelling correction for word."
def correction(word): 
    return max(candidates(word), key=P)

#"Generate possible spelling corrections for word."
def candidates(word): 
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

#"The subset of `words` that appear in the dictionary of WORDS."
def known(words): 
    return set(w for w in words if w in WORDS)

#"All edits that are one edit away from `word`."
def edits1(word):    
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

#"All edits that are two edits away from `word`."
def edits2(word): 
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))


def clean_text(text):
    ## Remove puncuation
    text = text.translate(string.punctuation)
    
    ## Convert words to lower case and split them
    text = text.lower().split()
    
    ## Remove stop words
    stops = set(stopwords.words("english"))
    #text = [w for w in text if not w in stops and len(w) >= 3]
    
    text = " ".join(text)
    ## Clean the text
    
    text = re.sub(r"\bi/c\b", "intercompany ", text)
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)    
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = re.sub(r"\bvat\b", "value added tax ", text)
    text = re.sub(r'\bwip\b', "work in progress ", text)
    text = re.sub(r"\bar\b", "accounts receivable ", text)
    text = re.sub(r"\bap\b", "accounts payable ", text)
    text = re.sub(r"\bcip\b", "carriage and insurance paid ", text)
    text = re.sub(r"\bfsb\b", "financial services board ", text)
    text = re.sub(r"\bemea\b", "europe middle east africa ", text)
    text = re.sub(r"\baccum\b", "accumulated ", text)
    text = re.sub(r"\bacc\b", "accumulated ", text)
    text = re.sub(r"\bprov\b", "provisions ", text)
    text = re.sub(r"\best\b", "estimated ", text)
    text = re.sub(r"\bdepr\b", "depreciation ", text)
    text = re.sub(r"\binterco\b", "intercompany ", text)
    text = re.sub(r"\bee\b", "employee ", text)
    text = re.sub(r"\bcogs\b", "cost of goods ", text)
    text = re.sub(r"\bfs\b", "financial services ", text)
    
    
    text = text.split()
    
    ## Stemming
    #stemmer = SnowballStemmer('english')
    #stemmed_words = [stemmer.stem(word) for word in text]
    
    ## Correct the spellings of text
    text = [correction(w) for w in text]
    ## Remove the stop words
    text = [w for w in text if not w in stops and len(w) >= 3]
    text = " ".join(text)
    #print(text)
    
    #text = " ".join(stemmed_words)
    return text

# %%
df1['CA_Account_Name'] = df1['CA_Account_Name'].map(lambda x: clean_text(x))
df2['CA_Account_Name'] = df2['CA_Account_Name'].map(lambda x: clean_text(x))

# %%
df1.head()
# Out:
#        CA_Account_Name CA_Account_Type
# 0          total asset          Assets
# 1                 cash          Assets
# 2  payrol cash account          Assets
# 3    short term invest          Assets
# 4     long term invest          Assets

# %%
df2.head()
# Out:
#            CA_Account_Name CA_Account_Type
# 59          mainten materi         Expense
# 170  sale revenu earn bill         Revenue
# 171       sale revenu bill         Revenue
# 172      sale revenu unbil         Revenue
# 173                hardwar         Revenue

# %%
### Create sequence
vocabulary_size = 20000
tokenizer1 = Tokenizer(num_words= vocabulary_size)
tokenizer1.fit_on_texts(df1['CA_Account_Name'])

tokenizer2 = Tokenizer(num_words= vocabulary_size)
tokenizer2.fit_on_texts(df2['CA_Account_Name'])

# %%
sequences1 = tokenizer1.texts_to_sequences(df1['CA_Account_Name'])
data1 = pad_sequences(sequences1, maxlen=8)

sequences2 = tokenizer2.texts_to_sequences(df2['CA_Account_Name'])
data2 = pad_sequences(sequences2, maxlen=8)

# %%
sequences1
# Out:
# [[175, 11],
#  [10],
#  [106, 10, 3],
#  [85, 24, 33],
#  [59, 24, 33],
#  [215, 56],
#  [357, 184, 113, 215, 56],
#  [10, 4],
#  [3, 1, 70],
#  [114, 1],
#  [300, 1],
#  [3, 1, 728],
#  [26, 264, 1],
#  [26, 23, 1],
#  [729, 265, 1],
#  [530, 23, 1],
#  [1],
#  [730, 1],
#  [153, 4],
#  [154, 197, 4],
#  [266, 301, 1],
#  [53, 1],
#  [73, 358, 1],
#  [73, 1],
#  [86, 10],
#  [302, 1],
#  [1, 120, 133],
#  [121, 34, 4],
#  [10, 4],
#  [37, 126, 1],
#  [99, 141, 65],
#  [15, 359],
#  [23, 1],
#  [127, 8, 1],
#  [127, 8, 2],
#  [87, 6],
#  [8],
#  [185, 8],
#  [235, 8],
#  [75, 28],
#  [5, 14, 13],
#  [155, 5, 14, 13],
#  [53, 303],
#  [5, 14, 35, 13],
#  [155, 5, 14, 35, 13],
#  [5, 35, 13],
#  [155, 5, 35, 13],
#  [5, 80, 13],
#  [155, 5, 80, 13],
#  [5, 78, 48, 13],
#  [155, 5, 78, 48, 13],
#  [147, 5, 13],
#  [429, 5, 13],
#  [93, 14, 13],
#  [93, 14, 35, 13],
#  [93, 35, 13],
#  [93, 80, 13],
#  [93, 78, 48, 13],
#  [126, 14],
#  [126, 80],
#  [126, 78, 48],
#  [126, 35],
#  [5, 304, 13],
#  [42],
#  [21, 45],
#  [60, 18],
#  [49],
#  [38],
#  [54, 88],
#  [176, 11],
#  [11, 4],
#  [300, 4],
#  [55, 22],
#  [55, 4],
#  [27, 29, 198, 45],
#  [31, 305, 198, 45],
#  [27, 29, 60, 18],
#  [31, 305, 60, 18],
#  [27, 29, 49],
#  [27, 29, 38],
#  [27, 29, 54, 88],
#  [27, 29, 176, 11],
#  [46, 15],
#  [46, 128],
#  [7, 15, 43],
#  [59, 24, 1],
#  [134],
#  [19, 1],
#  [9, 12, 1, 66],
#  [9, 12, 1, 199],
#  [9, 12, 1, 37],
#  [9, 12, 1, 216, 267],
#  [33, 177],
#  [9, 12, 1, 236],
#  [9, 12, 1, 236],
#  [9, 12, 1, 236],
#  [731, 41],
#  [91, 41],
#  [11, 91, 38],
#  [11, 91, 54],
#  [11, 91, 81, 18],
#  [31, 115, 38],
#  [31, 115, 54],
#  [31, 115, 81, 18],
#  [306, 13],
#  [26, 264],
#  [200, 1],
#  [26, 41],
#  [2, 17, 39],
#  [85, 24, 65],
#  [59, 24, 65],
#  [3, 2],
#  [16, 47],
#  [3, 2, 4],
#  [16, 28],
#  [22, 156, 4],
#  [302, 28, 2],
#  [37, 126, 2],
#  [44, 6, 2],
#  [79, 44, 6, 2],
#  [53, 44, 6, 39],
#  [19, 2],
#  [9, 12, 2, 217],
#  [9, 12, 2, 66],
#  [9, 12, 2, 199],
#  [9, 12, 2, 37],
#  [9, 12, 2, 216, 267],
#  [9, 12, 2, 531],
#  [16, 106],
#  [106, 4],
#  [16, 201],
#  [157, 165, 44, 6, 142],
#  [79, 165, 44, 6, 142],
#  [237, 142, 122],
#  [79, 34, 76, 6, 2],
#  [23, 2],
#  [53, 7, 15],
#  [82, 50],
#  [51, 57],
#  [110, 6, 2],
#  [111, 124, 64],
#  [2, 17, 59, 24, 65],
#  [59, 24, 20],
#  [53, 6],
#  [9, 12, 2],
#  [9, 12, 2, 236],
#  [9, 12, 2, 236],
#  [9, 12, 2, 236],
#  [56, 57],
#  [218, 61],
#  [50, 4],
#  [94, 50, 91, 218],
#  [94, 50, 91, 532, 44],
#  [94, 50, 26, 23, 44],
#  [71, 4],
#  [533, 4],
#  [430, 732],
#  [113, 40, 15],
#  [200, 2],
#  [300, 733],
#  [218, 534],
#  [306, 534],
#  [19, 30],
#  [30],
#  [166, 100],
#  [83, 58],
#  [32, 25],
#  [158, 535, 124],
#  [92, 67, 43],
#  [360],
#  [360],
#  [307, 3],
#  [536, 308],
#  [536, 734],
#  [186, 308],
#  [186],
#  [309],
#  [537, 310, 4],
#  [429, 5],
#  [10],
#  [85, 24, 33],
#  [3, 1, 70],
#  [114, 1],
#  [300, 1],
#  [26, 264, 1],
#  [26, 23, 1],
#  [1],
#  [153, 4],
#  [154, 197, 4],
#  [53, 1],
#  [73, 358, 1],
#  [73, 1],
#  [86, 10],
#  [1, 120, 133],
#  [121, 34, 4],
#  [10, 4],
#  [99, 141, 65],
#  [23, 1],
#  [127, 8, 2],
#  [87, 6],
#  [8],
#  [235, 8],
#  [75, 28],
#  [5, 14, 13],
#  [155, 5, 14, 13],
#  [53, 303],
#  [5, 14, 35, 13],
#  [155, 5, 14, 35, 13],
#  [5, 35, 13],
#  [155, 5, 35, 13],
#  [5, 80, 13],
#  [155, 5, 80, 13],
#  [5, 78, 48, 13],
#  [155, 5, 78, 48, 13],
#  [147, 5, 13],
#  [93, 14, 13],
#  [126, 14],
#  [126, 80],
#  [5, 304, 13],
#  [42],
#  [21, 45],
#  [60, 18],
#  [49],
#  [38],
#  [54, 88],
#  [176, 11],
#  [11, 4],
#  [55, 22],
#  [55, 4],
#  [27, 29, 198, 45],
#  [27, 29, 60, 18],
#  [27, 29, 49],
#  [27, 29, 38],
#  [27, 29, 54, 88],
#  [59, 24, 1],
#  [19, 1],
#  [9, 12, 1, 217],
#  [9, 12, 1, 66],
#  [9, 12, 1, 199],
#  [9, 12, 1, 37],
#  [9, 12, 1, 216, 267],
#  [33, 177],
#  [9, 12, 1, 236],
#  [91, 41],
#  [11, 91, 38],
#  [11, 91, 81, 18],
#  [31, 115, 38],
#  [31, 115, 81, 18],
#  [306, 13],
#  [26, 264],
#  [200, 1],
#  [2, 17, 39],
#  [3, 2],
#  [16, 47],
#  [3, 2, 4],
#  [16, 28],
#  [22, 156, 4],
#  [19, 2],
#  [9, 12, 2, 217],
#  [9, 12, 2, 66],
#  [9, 12, 2, 199],
#  [9, 12, 2, 37],
#  [9, 12, 2, 216, 267],
#  [9, 12, 2, 531],
#  [16, 106],
#  [106, 4],
#  [157, 165, 44, 6, 142],
#  [237, 142, 122],
#  [79, 34, 76, 6, 2],
#  [23, 2],
#  [82, 50],
#  [51, 57],
#  [2, 17, 59, 24, 65],
#  [59, 24, 20],
#  [53, 6],
#  [218, 61],
#  [50, 4],
#  [94, 50, 91, 218],
#  [19, 30],
#  [30],
#  [166, 100],
#  [83, 58],
#  [32, 25],
#  [92, 67, 43],
#  [431, 23, 143],
#  [360],
#  [360],
#  [307, 3],
#  [10],
#  [3, 1, 70],
#  [153, 4],
#  [73, 1],
#  [86, 10],
#  [10, 4],
#  [87, 6],
#  [75, 28],
#  [5, 14, 13],
#  [155, 5, 14, 13],
#  [5, 14, 35, 13],
#  [5, 78, 48, 13],
#  [147, 5, 13],
#  [42],
#  [19, 1],
#  [9, 12, 1, 66],
#  [9, 12, 1, 37],
#  [3, 2],
#  [3, 2, 4],
#  [19, 2],
#  [9, 12, 2, 66],
#  [9, 12, 2, 37],
#  [9, 12, 2, 216, 267],
#  [16, 106],
#  [79, 34, 76, 6, 2],
#  [82, 50],
#  [59, 24, 20],
#  [9, 12, 2],
#  [19, 30],
#  [30],
#  [166, 100],
#  [83, 58],
#  [32, 25],
#  [92, 67, 43],
#  [25, 11],
#  [85, 24, 33],
#  [157, 41, 432],
#  [56, 735],
#  [135, 56, 219, 361],
#  [135, 56, 68],
#  [143, 56, 68],
#  [101, 736, 3],
#  [101, 238, 3],
#  [23, 116, 737, 136],
#  [26],
#  [239, 26],
#  [240, 538, 26],
#  [10, 157, 15, 17],
#  [10, 63, 17],
#  [10],
#  [63, 17],
#  [3, 1],
#  [16, 23, 33, 44],
#  [75, 28],
#  [26],
#  [26, 94, 71],
#  [16, 23, 1],
#  [99, 26, 113],
#  [117, 33],
#  [117],
#  [143],
#  [49, 108],
#  [362, 18],
#  [54, 18],
#  [31, 7, 54, 18],
#  [49, 108],
#  [31, 7, 49, 108],
#  [21],
#  [31, 7, 21],
#  [46, 15],
#  [46, 128],
#  [55, 22],
#  [55, 4],
#  [11, 4],
#  [33],
#  [11],
#  [121, 34, 4],
#  [63, 738, 123, 17],
#  [63, 363, 123, 17],
#  [63, 268, 123, 17],
#  [19],
#  [23, 364, 57],
#  [24, 57],
#  [57, 144],
#  [85, 24, 187],
#  [94, 23, 364, 57],
#  [200, 433],
#  [3, 2],
#  [539, 311, 241],
#  [79, 34, 76, 6, 2],
#  [22, 156, 4],
#  [16, 66, 28],
#  [16, 201],
#  [59, 24, 65],
#  [30, 3, 2],
#  [30],
#  [63, 363, 123, 17],
#  [19],
#  [175, 434, 143],
#  [32, 25],
#  [269, 83, 58],
#  [32, 25],
#  [136, 44, 94, 540],
#  [148, 100],
#  [92, 67, 43],
#  [102, 541, 30, 542],
#  [739, 3, 308],
#  [543, 544],
#  [175, 11],
#  [10, 85, 24, 365],
#  [10],
#  [85, 24, 33],
#  [3, 1],
#  [114, 1],
#  [1],
#  [153, 4],
#  [154, 197, 4],
#  [53, 1],
#  [73, 358, 1],
#  [73, 1],
#  [86, 10],
#  [1, 120, 133],
#  [121, 34, 4],
#  [10, 4],
#  [99, 141, 65],
#  [15, 359],
#  [23, 1],
#  [87, 6],
#  [185, 8],
#  [75, 28],
#  [14, 13],
#  [42],
#  [21, 45],
#  [60, 18],
#  [49, 108],
#  [5, 216, 4, 3],
#  [54, 88],
#  [11, 4],
#  [55, 22],
#  [55, 4],
#  [27, 29, 21, 45],
#  [27, 29, 60, 18],
#  [27, 29, 49],
#  [27, 29, 38],
#  [27, 29, 54, 88],
#  [46, 15],
#  [46, 128],
#  [59, 24, 1],
#  [134],
#  [19, 1],
#  [9, 12, 1, 66],
#  [9, 12, 1, 199],
#  [9, 12, 1, 216, 267],
#  [33, 177],
#  [2, 17, 39],
#  [3, 2],
#  [16, 47],
#  [3, 2, 4],
#  [16, 28],
#  [22, 156, 4],
#  [44, 6, 2],
#  [79, 44, 6, 2],
#  [53, 44, 6, 39],
#  [19, 2],
#  [9, 12, 2, 66],
#  [9, 12, 2, 199],
#  [9, 12, 2, 37],
#  [16, 106],
#  [106, 4],
#  [16, 201],
#  [79, 34, 76, 6, 2],
#  [23, 2],
#  [53, 7, 15],
#  [82, 50],
#  [51, 57],
#  [111, 124, 64],
#  [2, 17, 59, 24, 65],
#  [59, 24, 20],
#  [53, 6],
#  [19, 30],
#  [30],
#  [166, 100],
#  [83, 58],
#  [32, 25],
#  [92, 67, 43],
#  [85, 24, 33],
#  [26],
#  [10, 157, 15, 17],
#  [10, 63, 17],
#  [26],
#  [26, 94, 71],
#  [16, 23, 1],
#  [99, 26, 113],
#  [117, 33],
#  [117],
#  [143],
#  [362, 18],
#  [54, 18],
#  [31, 7, 54, 18],
#  [49, 108],
#  [31, 7, 49, 108],
#  [21],
#  [31, 7, 21],
#  [33],
#  [11],
#  [63, 363, 123, 17],
#  [63, 268, 123, 17],
#  [19],
#  [23, 364, 57],
#  [85, 24, 187],
#  [94, 23, 364, 57],
#  [200, 433],
#  [3, 2],
#  [539, 311, 241],
#  [16, 66, 28],
#  [16, 201],
#  [59, 24, 65],
#  [30],
#  [63, 363, 123, 17],
#  [19],
#  [175, 434, 143],
#  [269, 83, 58],
#  [32, 25],
#  [136, 44, 94, 540],
#  [136, 44, 435, 740, 220],
#  [148, 100],
#  [92, 67, 43],
#  [543, 544],
#  [175, 11],
#  [10],
#  [85, 24, 33],
#  [3, 1],
#  [114, 1],
#  [1],
#  [153, 4],
#  [73, 358, 1],
#  [73, 1],
#  [86, 10],
#  [1, 120, 133],
#  [121, 34, 4],
#  [10, 4],
#  [99, 141, 65],
#  [23, 1],
#  [545, 6],
#  [185, 8],
#  [75, 28],
#  [5, 14, 13],
#  [5, 14, 35, 13],
#  [5, 80, 13],
#  [5, 80, 35, 13],
#  [5, 78, 48, 13],
#  [147, 5, 13],
#  [5, 1],
#  [5, 72, 48, 14],
#  [149, 93, 14, 312, 125],
#  [5, 72, 48, 14, 35],
#  [149, 93, 14, 35, 312, 125],
#  [5, 72, 48, 80],
#  [149, 93, 80, 312, 125],
#  [5, 72, 48, 80, 35],
#  [149, 93, 80, 35, 312, 125],
#  [5, 72, 48, 78, 48],
#  [149, 93, 78, 48, 312, 125],
#  [126, 14],
#  [126, 80],
#  [126, 78, 48],
#  [126, 35],
#  [42],
#  [21, 45],
#  [60, 18],
#  [49],
#  [38],
#  [54, 88],
#  [11, 4],
#  [118, 48],
#  [118, 48, 4],
#  [27, 7, 21, 45],
#  [27, 7, 60, 18],
#  [27, 7, 49],
#  [27, 7, 38],
#  [27, 7, 54, 88],
#  [46, 15],
#  [46, 128],
#  [7, 15, 43],
#  [59, 24, 1],
#  [19, 1],
#  [9, 12, 1, 66],
#  [9, 12, 1, 199],
#  [33, 177],
#  [2, 17, 39],
#  [3, 2],
#  [16, 47],
#  [3, 2, 4],
#  [16, 28],
#  [22, 156, 4],
#  [19, 2],
#  [9, 12, 2, 66],
#  [9, 12, 2, 37],
#  [16, 106],
#  [106, 4],
#  [79, 34, 76, 6, 2],
#  [82, 50],
#  [51, 57],
#  [51, 69],
#  [2, 17, 59, 24, 65],
#  [59, 24, 20],
#  [53, 6],
#  [19, 30],
#  [30],
#  [166, 100],
#  [83, 58],
#  [32, 25],
#  [92, 67, 43],
#  [313, 366],
#  [313, 366, 270, 436],
#  [313, 366, 54, 88],
#  [31, 128, 313, 366],
#  [202],
#  [31, 437, 202],
#  [134],
#  [134, 4],
#  [31, 437, 134],
#  [21],
#  [21, 438, 42],
#  [21, 4, 3],
#  [31, 7, 21],
#  [60],
#  [103, 7, 95, 60],
#  [18, 203],
#  [18, 203, 741],
#  [103, 7, 18, 203],
#  [108, 314],
#  [103, 439, 108, 314],
#  [204, 167, 18],
#  [204, 167, 18, 4],
#  [103, 439, 204, 742, 743],
#  [54],
#  [54, 4],
#  [103, 439, 744],
#  [91, 11],
#  [103, 7, 91, 11],
#  [546, 11, 4],
#  [205, 3, 745],
#  [746, 3, 46, 11],
#  [61, 64, 747, 18],
#  [18, 91, 110],
#  [103, 29, 18, 91, 110],
#  [96, 271, 119, 52],
#  [96, 271, 547, 119, 52],
#  [1, 119, 52],
#  [1, 440, 52],
#  [1, 177],
#  [1, 119, 52],
#  [13, 43, 1, 119, 52],
#  [59, 24, 1],
#  [748, 114, 1],
#  [1, 548],
#  [75, 91, 28],
#  [59, 24, 749],
#  [13, 43, 59, 24, 1],
#  [5, 750],
#  [188, 5],
#  [5, 89, 14],
#  [89, 14],
#  [89, 14, 22],
#  [367, 549, 89, 14],
#  [35, 137, 22, 89, 14],
#  [550, 137, 89, 14],
#  [129, 239],
#  [441, 104, 137],
#  [137, 97],
#  [104, 36],
#  [14, 104, 36],
#  [14, 35, 22, 104, 36],
#  [367, 549, 104, 36],
#  [35, 137, 22, 104, 36],
#  [550, 137, 104, 36],
#  [188, 104, 36],
#  [36, 242],
#  [188, 36, 242],
#  [72, 97],
#  [72, 97, 22, 442],
#  [72, 97, 206],
#  [188, 72, 97],
#  [64, 3, 36, 37],
#  [61, 64, 3, 77],
#  [188, 5, 72, 97, 315],
#  [3, 1, 68],
#  [3, 1, 547],
#  [3, 1, 107],
#  [551, 3, 1],
#  [443, 34, 552],
#  [13, 43, 70, 1],
#  [119, 52],
#  [9, 12, 1],
#  [177],
#  [9, 12, 1, 368],
#  [9, 12, 1, 221],
#  [9, 12, 1, 272],
#  [9, 12, 1, 168],
#  [9, 12, 119, 52],
#  [9, 12, 1, 189],
#  [9, 12, 1, 74, 190],
#  [9, 12, 1, 74, 37],
#  [9, 12, 1, 74, 222],
#  [9, 12, 1, 74, 186],
#  [13, 43, 315],
#  [1, 548],
#  [553, 61],
#  [10, 61],
#  [61],
#  [369, 26, 273],
#  [1, 273],
#  [44, 6, 169],
#  [8, 169],
#  [1, 119, 52],
#  [1, 440, 52],
#  [1, 751],
#  [1, 119, 52],
#  [178, 19],
#  [39, 1],
#  [207, 752, 51],
#  [39, 26],
#  [554, 58, 444],
#  [1, 77],
#  [1, 223, 316],
#  [39, 555, 59, 24, 1],
#  [39, 1],
#  [13, 43, 39, 1, 315],
#  [67, 43],
#  [75, 28, 556, 44, 62, 3],
#  [75, 218],
#  [75, 200, 170],
#  [75, 23, 188],
#  [16, 753, 44],
#  [16, 23, 1],
#  [11, 754, 75, 28],
#  [71],
#  [13, 43, 85, 24, 755],
#  [10, 370],
#  [445, 557],
#  [445, 557, 556],
#  [10, 144],
#  [446, 756],
#  [446, 558],
#  [446, 16],
#  [559, 560],
#  [558, 757],
#  [559, 560, 16],
#  [179, 3, 317],
#  [447, 3, 317, 16],
#  [447, 3, 150],
#  [447, 3, 150, 16],
#  [86, 64],
#  [96, 58],
#  [758, 96, 58],
#  [243, 15, 759, 561, 15],
#  [191, 113, 448, 318],
#  [32, 25],
#  [6, 112, 15, 760, 6, 449],
#  [6, 112, 15, 761, 6, 449],
#  [6, 112, 15, 762, 6, 449],
#  [103, 450, 7, 176, 135, 11],
#  [103, 450, 7, 21, 42, 763],
#  [103, 450, 7, 60, 18],
#  [40, 764, 208],
#  [40, 208],
#  [40, 765],
#  [451, 371, 766, 6],
#  [451, 452, 6],
#  [451, 6],
#  [40],
#  [17, 372],
#  [17, 372],
#  [20, 119, 52],
#  [20, 440, 52],
#  [20, 177],
#  [20, 119, 52],
#  [59, 24, 20],
#  [59, 24, 20],
#  [39, 26, 105, 159],
#  [39, 555, 767, 562],
#  [39, 20, 105, 563],
#  [61, 51],
#  [72, 97, 206],
#  [72, 97, 22, 442],
#  [188, 72, 97],
#  [3, 2, 68],
#  [768, 443, 3, 2, 68],
#  [452],
#  [20, 546, 11],
#  [443, 769],
#  [119, 52],
#  [9, 12, 2],
#  [177],
#  [9, 12, 2, 368],
#  [9, 12, 2, 221],
#  [9, 12, 2, 272],
#  [9, 12, 2, 168],
#  [9, 12, 119, 52],
#  [9, 12, 2, 189],
#  [9, 12, 2, 74, 190],
#  [9, 12, 2, 74, 37],
#  [9, 12, 2, 74, 222],
#  [9, 12, 2, 74, 186],
#  [39, 20, 105, 563],
#  [44, 6, 20],
#  [453, 770, 6, 20],
#  [371, 44, 6],
#  [371, 110, 6],
#  [319, 160, 320, 161, 208],
#  [771, 6, 83],
#  [90, 8, 274, 116],
#  [90, 8, 34, 162, 274, 116],
#  [90, 8, 454, 274, 13],
#  [319, 90, 8, 37, 373, 374, 564, 274, 116],
#  [319, 90, 8, 36, 373, 374, 455, 274, 116],
#  [456, 90, 8, 274, 116],
#  [90, 8, 375, 116],
#  [90, 8, 34, 162, 275, 244],
#  [90, 8, 454, 275, 244],
#  [319, 90, 8, 36, 373, 374, 455, 275, 116],
#  [456, 90, 8, 375, 565],
#  [90, 8, 375, 116],
#  [90, 8, 34, 162, 275, 116],
#  [90, 8, 454, 275, 116],
#  [319, 90, 8, 36, 373, 374, 455, 275, 116],
#  [456, 90, 8, 375, 565],
#  [145, 8],
#  [145, 8, 453],
#  [371, 145, 8, 101, 564],
#  [145, 8, 772, 321],
#  [8, 2],
#  [160, 224, 276],
#  [566, 6],
#  [160, 224, 276],
#  [19],
#  [30],
#  [122, 87, 6],
#  [6, 130, 773],
#  [6, 83],
#  [122, 306, 6],
#  [243, 131, 56, 457, 160, 567, 457],
#  [243, 131, 56, 568, 4, 3],
#  [160, 320, 774, 4, 3],
#  [243, 131, 56, 568, 83],
#  [266, 131, 56, 161, 4, 3],
#  [266, 131, 56, 161, 83],
#  [277, 165, 41],
#  [192, 458, 130],
#  [122, 192, 458, 130, 3],
#  [567, 376, 569],
#  [119, 442],
#  [68, 570, 63],
#  [192, 458, 130],
#  [20, 273],
#  [192, 245, 20],
#  [553, 278],
#  [201],
#  [4, 3, 775, 322, 776],
#  [39, 26],
#  [39, 777, 59, 24, 26],
#  [39, 26],
#  [20, 119, 52],
#  [20, 202, 52],
#  [20, 177],
#  [20, 119, 52],
#  [778, 20],
#  [57, 1],
#  [39, 20],
#  [16, 192, 245],
#  [192, 245, 20],
#  [779, 72, 377],
#  [16, 277, 165],
#  [16, 208, 22],
#  [16, 208, 64],
#  [16, 780, 131, 56, 161],
#  [16, 322, 131, 781, 457],
#  [16, 322, 22],
#  [10],
#  [3, 1],
#  [1],
#  [53, 1],
#  [73, 1],
#  [86, 10],
#  [1, 120, 133],
#  [4, 459],
#  [10, 4],
#  [99, 141, 65],
#  [127, 8, 1],
#  [127, 8, 2],
#  [460, 6],
#  [185, 8],
#  [235, 8],
#  [75, 28],
#  [5],
#  [5, 14, 13],
#  [5, 14, 35, 13],
#  [5, 35, 13],
#  [5, 80, 13],
#  [5, 78, 48, 13],
#  [147, 5, 13],
#  [42],
#  [21, 45],
#  [60, 18],
#  [49],
#  [38],
#  [54, 88],
#  [571],
#  [11, 4],
#  [55, 22],
#  [55, 4],
#  [27, 29, 198, 45],
#  [27, 29, 60, 18],
#  [27, 29, 49],
#  [27, 29, 38],
#  [27, 29, 54, 88],
#  [27, 29, 571],
#  [46, 15],
#  [46, 128],
#  [7, 15, 43],
#  [134],
#  [19, 1],
#  [9, 12, 1, 98, 221],
#  [9, 12, 1, 98, 272],
#  [9, 12, 1, 98, 168],
#  [9, 12, 1, 98, 189],
#  [2, 17, 39],
#  [3, 2],
#  [16, 47],
#  [3, 2, 4],
#  [15, 171],
#  [19, 2],
#  [9, 12, 2, 98, 221],
#  [9, 12, 2, 98, 272],
#  [9, 12, 2, 98, 168],
#  [9, 12, 2, 98, 189],
#  [106, 4],
#  [320, 265],
#  [82, 50],
#  [51, 572],
#  [51, 57],
#  [19],
#  [30],
#  [166, 100],
#  [83, 782],
#  [32, 25],
#  [32, 25],
#  [67, 43],
#  [184, 172],
#  [113, 172],
#  [58],
#  [96, 170, 3],
#  [573, 170],
#  [180, 170],
#  [117, 783, 96, 170],
#  [160, 46, 40],
#  [784, 46, 125],
#  [46, 15],
#  [46, 125, 246, 66],
#  [46, 125, 189],
#  [46, 125, 785],
#  [243, 15],
#  [59, 24, 136, 58, 184],
#  [15, 94, 574],
#  [243, 15, 786],
#  [136, 58, 184, 59, 24],
#  [15, 787, 323, 181],
#  [246, 15],
#  [461, 200, 15],
#  [788, 15],
#  [789, 3],
#  [462, 554, 58, 378],
#  [448, 318, 105, 102],
#  [32, 25],
#  [113, 463, 158],
#  [191, 113, 279, 575],
#  [79],
#  [379],
#  [324, 576],
#  [577],
#  [225, 380],
#  [225, 52],
#  [52, 381, 159],
#  [],
#  [33, 181],
#  [18, 181, 79],
#  [18, 181, 379],
#  [18, 181, 324, 576],
#  [18, 181, 577],
#  [18, 181, 225, 380],
#  [18, 181, 225, 52],
#  [18, 181, 52, 381, 159],
#  [18, 181],
#  [33, 181],
#  [15, 464, 790],
#  [15, 122, 271, 33],
#  [209, 382],
#  [791, 209],
#  [246, 15, 3, 1],
#  [578, 128],
#  [160, 46, 40],
#  [58, 184, 792],
#  [246, 40],
#  [40, 452],
#  [40, 465, 325],
#  [40, 163, 113],
#  [280, 40],
#  [40, 208, 326, 301],
#  [40, 44, 6],
#  [40, 11, 579, 466, 793],
#  [40, 794],
#  ...]

# %%
data1[0]
# Out:
# array([  0,   0,   0,   0,   0,   0, 175,  11])

# %%
model1 = Sequential()
model1.add(Embedding(20000, 100, input_length=8))
model1.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model2 = Sequential()
model2.add(Embedding(20000, 100, input_length=8))
model2.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model2.add(Dense(1, activation='sigmoid'))
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
## Fit the model
model1.fit(data1, np.array(labels1), validation_split=0.4, epochs=50)
# Out:
# Train on 2306 samples, validate on 1538 samples
# Epoch 1/50
# 2306/2306 [==============================] - 17s 7ms/step - loss: 0.3529 - acc: 0.0655 - val_loss: 2.0417 - val_acc: 0.0754
# Epoch 2/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -1.7039 - acc: 0.2793 - val_loss: -1.9287 - val_acc: 0.4012
# Epoch 3/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -3.6735 - acc: 0.4731 - val_loss: -1.9677 - val_acc: 0.4720
# Epoch 4/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.0805 - acc: 0.5199 - val_loss: -2.4376 - val_acc: 0.5254
# Epoch 5/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.2460 - acc: 0.5377 - val_loss: -2.3614 - val_acc: 0.5247
# Epoch 6/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.4297 - acc: 0.5512 - val_loss: -2.3164 - val_acc: 0.5156
# Epoch 7/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.5051 - acc: 0.5559 - val_loss: -2.2631 - val_acc: 0.5280
# Epoch 8/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.5310 - acc: 0.5642 - val_loss: -2.3577 - val_acc: 0.5371
# Epoch 9/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.6303 - acc: 0.5668 - val_loss: -2.3563 - val_acc: 0.5371
# Epoch 10/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.6506 - acc: 0.5685 - val_loss: -2.3134 - val_acc: 0.5351
# Epoch 11/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.7140 - acc: 0.5711 - val_loss: -2.2638 - val_acc: 0.5592
# Epoch 12/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.7511 - acc: 0.5768 - val_loss: -2.1465 - val_acc: 0.5384
# Epoch 13/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.7802 - acc: 0.5785 - val_loss: -2.2469 - val_acc: 0.5540
# Epoch 14/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.7863 - acc: 0.5833 - val_loss: -2.1496 - val_acc: 0.5371
# Epoch 15/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8146 - acc: 0.5828 - val_loss: -2.1579 - val_acc: 0.5475
# Epoch 16/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8245 - acc: 0.5824 - val_loss: -2.0075 - val_acc: 0.5475
# Epoch 17/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8071 - acc: 0.5863 - val_loss: -2.1156 - val_acc: 0.5540
# Epoch 18/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.7710 - acc: 0.5820 - val_loss: -2.1092 - val_acc: 0.5384
# Epoch 19/50
# 2306/2306 [==============================] - 7s 3ms/step - loss: -4.8363 - acc: 0.5815 - val_loss: -2.1615 - val_acc: 0.5598
# Epoch 20/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8440 - acc: 0.5872 - val_loss: -1.9779 - val_acc: 0.5449
# Epoch 21/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8773 - acc: 0.5924 - val_loss: -2.0948 - val_acc: 0.5546
# Epoch 22/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8819 - acc: 0.5893 - val_loss: -1.9990 - val_acc: 0.5494
# Epoch 23/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.9133 - acc: 0.5919 - val_loss: -1.9771 - val_acc: 0.5475
# Epoch 24/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.8959 - acc: 0.5915 - val_loss: -2.0251 - val_acc: 0.5520
# Epoch 25/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.8917 - acc: 0.5876 - val_loss: -1.9797 - val_acc: 0.5455
# Epoch 26/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9126 - acc: 0.5885 - val_loss: -2.0069 - val_acc: 0.5540
# Epoch 27/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9366 - acc: 0.5976 - val_loss: -1.8613 - val_acc: 0.5319
# Epoch 28/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9286 - acc: 0.5906 - val_loss: -1.8872 - val_acc: 0.5442
# Epoch 29/50
# 2306/2306 [==============================] - 7s 3ms/step - loss: -4.9370 - acc: 0.5915 - val_loss: -1.9459 - val_acc: 0.5540
# Epoch 30/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.9355 - acc: 0.5932 - val_loss: -1.9392 - val_acc: 0.5514
# Epoch 31/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.9411 - acc: 0.5971 - val_loss: -1.9373 - val_acc: 0.5475
# Epoch 32/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.9486 - acc: 0.5950 - val_loss: -1.7276 - val_acc: 0.5293
# Epoch 33/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.8669 - acc: 0.5837 - val_loss: -1.8834 - val_acc: 0.5468
# Epoch 34/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.9557 - acc: 0.5963 - val_loss: -1.8706 - val_acc: 0.5520
# Epoch 35/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9758 - acc: 0.5971 - val_loss: -1.8545 - val_acc: 0.5475
# Epoch 36/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9829 - acc: 0.5967 - val_loss: -1.7840 - val_acc: 0.5423
# Epoch 37/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -4.9802 - acc: 0.5967 - val_loss: -1.8906 - val_acc: 0.5579
# Epoch 38/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.9809 - acc: 0.5958 - val_loss: -1.8381 - val_acc: 0.5501
# Epoch 39/50
# 2306/2306 [==============================] - 7s 3ms/step - loss: -5.0009 - acc: 0.5963 - val_loss: -1.8320 - val_acc: 0.5494
# Epoch 40/50
# 2306/2306 [==============================] - 7s 3ms/step - loss: -5.0011 - acc: 0.5997 - val_loss: -1.8282 - val_acc: 0.5488
# Epoch 41/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -5.0137 - acc: 0.5980 - val_loss: -1.8454 - val_acc: 0.5462
# Epoch 42/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -5.0107 - acc: 0.5984 - val_loss: -1.7737 - val_acc: 0.5455
# Epoch 43/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -5.0090 - acc: 0.5963 - val_loss: -1.9028 - val_acc: 0.5611
# Epoch 44/50
# 2306/2306 [==============================] - 5s 2ms/step - loss: -4.9916 - acc: 0.6023 - val_loss: -1.6249 - val_acc: 0.5241
# Epoch 45/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -4.9915 - acc: 0.5928 - val_loss: -1.9274 - val_acc: 0.5572
# Epoch 46/50
# 2306/2306 [==============================] - 6s 2ms/step - loss: -5.0120 - acc: 0.5976 - val_loss: -1.8419 - val_acc: 0.5553
# Epoch 47/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -5.0227 - acc: 0.6002 - val_loss: -1.8167 - val_acc: 0.5494
# Epoch 48/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -5.0396 - acc: 0.5971 - val_loss: -1.7993 - val_acc: 0.5501
# Epoch 49/50
# 2306/2306 [==============================] - 8s 3ms/step - loss: -5.0330 - acc: 0.6002 - val_loss: -1.8340 - val_acc: 0.5572
# Epoch 50/50
# 2306/2306 [==============================] - 6s 3ms/step - loss: -5.0390 - acc: 0.6019 - val_loss: -1.7760 - val_acc: 0.5507

# %%
## Fit the model
model2.fit(data2, np.array(labels2), validation_split=0.4, epochs=50)
# Out:
# Train on 1766 samples, validate on 1178 samples
# Epoch 1/50
# 1766/1766 [==============================] - 14s 8ms/step - loss: 0.5463 - acc: 0.7639 - val_loss: 0.4559 - val_acc: 0.8014
# Epoch 2/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.3860 - acc: 0.8086 - val_loss: 0.3382 - val_acc: 0.8735
# Epoch 3/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.2671 - acc: 0.8907 - val_loss: 0.3141 - val_acc: 0.8659
# Epoch 4/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.2004 - acc: 0.9179 - val_loss: 0.3370 - val_acc: 0.8548
# Epoch 5/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1675 - acc: 0.9343 - val_loss: 0.3852 - val_acc: 0.8243
# Epoch 6/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1651 - acc: 0.9354 - val_loss: 0.3502 - val_acc: 0.8438
# Epoch 7/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1428 - acc: 0.9462 - val_loss: 0.3757 - val_acc: 0.8455
# Epoch 8/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1342 - acc: 0.9479 - val_loss: 0.3891 - val_acc: 0.8438
# Epoch 9/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.1335 - acc: 0.9473 - val_loss: 0.3675 - val_acc: 0.8497
# Epoch 10/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1295 - acc: 0.9479 - val_loss: 0.3670 - val_acc: 0.8514
# Epoch 11/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1282 - acc: 0.9485 - val_loss: 0.4402 - val_acc: 0.8472
# Epoch 12/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1187 - acc: 0.9507 - val_loss: 0.4099 - val_acc: 0.8438
# Epoch 13/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1252 - acc: 0.9507 - val_loss: 0.3809 - val_acc: 0.8506
# Epoch 14/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.1137 - acc: 0.9524 - val_loss: 0.4193 - val_acc: 0.8608
# Epoch 15/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1110 - acc: 0.9507 - val_loss: 0.4045 - val_acc: 0.8574
# Epoch 16/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1056 - acc: 0.9553 - val_loss: 0.4461 - val_acc: 0.8523
# Epoch 17/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1102 - acc: 0.9519 - val_loss: 0.4053 - val_acc: 0.8523
# Epoch 18/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1054 - acc: 0.9553 - val_loss: 0.4473 - val_acc: 0.8489
# Epoch 19/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.1020 - acc: 0.9592 - val_loss: 0.4661 - val_acc: 0.8540
# Epoch 20/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0969 - acc: 0.9621 - val_loss: 0.4810 - val_acc: 0.8565
# Epoch 21/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0936 - acc: 0.9621 - val_loss: 0.4427 - val_acc: 0.8676
# Epoch 22/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0911 - acc: 0.9655 - val_loss: 0.4780 - val_acc: 0.8565
# Epoch 23/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.0899 - acc: 0.9609 - val_loss: 0.4672 - val_acc: 0.8531
# Epoch 24/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.0887 - acc: 0.9609 - val_loss: 0.4535 - val_acc: 0.8421
# Epoch 25/50
# 1766/1766 [==============================] - 4s 3ms/step - loss: 0.0875 - acc: 0.9598 - val_loss: 0.4729 - val_acc: 0.8676
# Epoch 26/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0851 - acc: 0.9638 - val_loss: 0.4811 - val_acc: 0.8557
# Epoch 27/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0823 - acc: 0.9649 - val_loss: 0.5151 - val_acc: 0.8650
# Epoch 28/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0831 - acc: 0.9649 - val_loss: 0.4534 - val_acc: 0.8701
# Epoch 29/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0779 - acc: 0.9683 - val_loss: 0.5558 - val_acc: 0.8557
# Epoch 30/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0791 - acc: 0.9660 - val_loss: 0.5367 - val_acc: 0.8531
# Epoch 31/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0758 - acc: 0.9660 - val_loss: 0.5315 - val_acc: 0.8616
# Epoch 32/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0775 - acc: 0.9683 - val_loss: 0.5685 - val_acc: 0.8379
# Epoch 33/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0769 - acc: 0.9700 - val_loss: 0.5128 - val_acc: 0.8565
# Epoch 34/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.0656 - acc: 0.9700 - val_loss: 0.6044 - val_acc: 0.8506
# Epoch 35/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0715 - acc: 0.9689 - val_loss: 0.6046 - val_acc: 0.8413
# Epoch 36/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0678 - acc: 0.9706 - val_loss: 0.5464 - val_acc: 0.8514
# Epoch 37/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0647 - acc: 0.9717 - val_loss: 0.6067 - val_acc: 0.8548
# Epoch 38/50
# 1766/1766 [==============================] - 6s 3ms/step - loss: 0.0626 - acc: 0.9762 - val_loss: 0.5882 - val_acc: 0.8557
# Epoch 39/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0613 - acc: 0.9723 - val_loss: 0.6142 - val_acc: 0.8574 loss: 0.0615 - acc:
# Epoch 40/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0631 - acc: 0.9723 - val_loss: 0.5830 - val_acc: 0.8480
# Epoch 41/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0594 - acc: 0.9734 - val_loss: 0.6398 - val_acc: 0.8574
# Epoch 42/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0581 - acc: 0.9717 - val_loss: 0.6263 - val_acc: 0.8608
# Epoch 43/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0578 - acc: 0.9768 - val_loss: 0.6482 - val_acc: 0.8650
# Epoch 44/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.0572 - acc: 0.9757 - val_loss: 0.6832 - val_acc: 0.8430
# Epoch 45/50
# 1766/1766 [==============================] - 5s 3ms/step - loss: 0.0633 - acc: 0.9734 - val_loss: 0.5961 - val_acc: 0.8565
# Epoch 46/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0579 - acc: 0.9757 - val_loss: 0.6418 - val_acc: 0.8625
# Epoch 47/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0553 - acc: 0.9734 - val_loss: 0.6794 - val_acc: 0.8379
# Epoch 48/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0570 - acc: 0.9723 - val_loss: 0.7226 - val_acc: 0.8540
# Epoch 49/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0553 - acc: 0.9745 - val_loss: 0.6598 - val_acc: 0.8591
# Epoch 50/50
# 1766/1766 [==============================] - 4s 2ms/step - loss: 0.0525 - acc: 0.9757 - val_loss: 0.7066 - val_acc: 0.8616
